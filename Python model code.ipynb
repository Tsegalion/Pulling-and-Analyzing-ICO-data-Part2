# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Tsega\ICOdb.csv")
df
# Out:
#                       Project            Category
# 0     Manta Network Crowdloan            Protocol  \
# 1                        HALO  Blockchain Service
# 2                       Mizar            Platform
# 3                        G4AL            Platform
# 4                    SHELTERZ  Blockchain Service
# ...                       ...                 ...
# 1358                    Hatom                DeFi
# 1359                   Arkham  Blockchain Service
# 1360                 EMG Coin            Platform
# 1361              SophiaVerse               AI/VR
# 1362            Immunify.Life  Blockchain Service
#
#                                             Description  Start_date
# 0     Manta Network is the plug-and-play privacy-pre...  2023-11-04  \
# 1     HALO cooperates with the Decemberentralized 3D...  2023-03-02
# 2     Mizar is a next-gen trading platform where tra...  2023-03-06
# 3     The G4AL Platform is the easiest and fastest a...  2023-03-09
# 4     SHELTERZ is an accommodation booking service w...  2023-02-18
# ...                                                 ...         ...
# 1358  Hatom is a decentralized, algorithmic protocol...  2023-07-17
# 1359  An Intel-To-Earn Token Powering the Deanonymiz...  2023-07-11
# 1360  EMG Coin is the E-commerce Telecom platform to...  2023-07-24
# 1361  Sophia is a platform for the pursuit of useful...  2023-07-18
# 1362  Immunify.Life is a transformative and self-sus...  2023-07-20
#
#         End_date  Raised_usd Ticker        Platform  ICO_price
# 0     2023-03-01   6600000.0  MANTA        Polkadot        NaN  \
# 1     2023-03-03         NaN   HALO   Binance Chain      0.020
# 2     2023-03-08   3400000.0    MZR   Binance Chain      0.000
# 3     2023-03-11   1600000.0    GGT        Ethereum      0.000
# 4     2023-03-05   3590000.0   TERZ   Binance Chain      0.020
# ...          ...         ...    ...             ...        ...
# 1358  2023-07-20   8000000.0    HTM  Own Blockchain      0.400
# 1359  2023-07-18  12000000.0   ARKM   Binance Chain      0.050
# 1360  2023-07-24    150000.0    EMG        Ethereum      0.065
# 1361  2023-07-31   5640000.0   SOPH   Binance Chain      0.030
# 1362  2023-07-22   2160000.0    IMM  Own Blockchain      0.100
#
#       Fundraise_goal   Total_token   Sold Token_Role
# 0                NaN  1.000000e+09  15.60    Utility
# 1            50000.0  5.000000e+08    NaN    Utility
# 2           200000.0  1.000000e+10    NaN    Utility
# 3           500000.0  1.000000e+10  16.25    Utility
# 4           510000.0  1.000000e+09  18.00    Utility
# ...              ...           ...    ...        ...
# 1358       2000000.0  1.000000e+08  25.84    Utility
# 1359       2500000.0  1.000000e+09   5.00    Utility
# 1360        200000.0  8.000000e+08  31.00    Utility
# 1361       1600000.0  1.000000e+09    NaN    Utility
# 1362        100000.0  3.000000e+08   1.00    Utility
#
# [1363 rows x 13 columns]

# %%
# Convert start date to a date time
df['Start_date'] = pd.to_datetime(df['Start_date'])

# Convert end date to a date time
df['End_date'] = pd.to_datetime(df['End_date'])

# %%
# Create a date dimension table
Date = df[['Start_date', 'End_date']].drop_duplicates().reset_index(drop=True)
Date['Start_day'] = Date['Start_date'].dt.day
Date['Start_month'] = Date['Start_date'].dt.month
Date['Start_year'] = Date['Start_date'].dt.year
Date['Start_weekday'] = Date['Start_date'].dt.weekday

Date['End_day'] = Date['End_date'].dt.day
Date['End_month'] = Date['End_date'].dt.month
Date['End_year'] = Date['End_date'].dt.year
Date['End_weekday'] = Date['End_date'].dt.weekday

# Assign the dateID with the index number and add "DA" prefix
Date['DateID'] = 'DA' + Date.index.astype(str)

# Rearrange the table
Date = Date[['DateID', 'Start_date', 'Start_year', 'Start_month', 'Start_weekday', 'Start_day', 'End_date', 'End_year', 'End_month', 'End_weekday', 'End_day']]
Date
# Out:
#       DateID Start_date  Start_year  Start_month  Start_weekday  Start_day
# 0        DA0 2023-11-04        2023           11              5          4  \
# 1        DA1 2023-03-02        2023            3              3          2
# 2        DA2 2023-03-06        2023            3              0          6
# 3        DA3 2023-03-09        2023            3              3          9
# 4        DA4 2023-02-18        2023            2              5         18
# ...      ...        ...         ...          ...            ...        ...
# 1228  DA1228 2023-07-17        2023            7              0         17
# 1229  DA1229 2023-07-11        2023            7              1         11
# 1230  DA1230 2023-07-24        2023            7              0         24
# 1231  DA1231 2023-07-18        2023            7              1         18
# 1232  DA1232 2023-07-20        2023            7              3         20
#
#        End_date  End_year  End_month  End_weekday  End_day
# 0    2023-03-01      2023          3            2        1
# 1    2023-03-03      2023          3            4        3
# 2    2023-03-08      2023          3            2        8
# 3    2023-03-11      2023          3            5       11
# 4    2023-03-05      2023          3            6        5
# ...         ...       ...        ...          ...      ...
# 1228 2023-07-20      2023          7            3       20
# 1229 2023-07-18      2023          7            1       18
# 1230 2023-07-24      2023          7            0       24
# 1231 2023-07-31      2023          7            0       31
# 1232 2023-07-22      2023          7            5       22
#
# [1233 rows x 11 columns]

# %%
Date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1233 entries, 0 to 1232
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DateID         1233 non-null   object
#  1   Start_date     1233 non-null   datetime64[ns]
#  2   Start_year     1233 non-null   int32
#  3   Start_month    1233 non-null   int32
#  4   Start_weekday  1233 non-null   int32
#  5   Start_day      1233 non-null   int32
#  6   End_date       1233 non-null   datetime64[ns]
#  7   End_year       1233 non-null   int32
#  8   End_month      1233 non-null   int32
#  9   End_weekday    1233 non-null   int32
#  10  End_day        1233 non-null   int32
# dtypes: datetime64[ns](2), int32(8), object(1)
# memory usage: 67.6+ KB

# %%
# Create a Project dimension table
Project = df[['Project', 'Description', 'Ticker']].drop_duplicates().reset_index(drop=True)

# Assign the PlatformID with the index number and add "PRO" prefix
Project['ProjectID'] = 'PRO' + Project.index.astype(str)

# Rearrange the table
Project = Project[['ProjectID', 'Project', 'Description', 'Ticker']]
Project
# Out:
#      ProjectID                  Project
# 0         PRO0  Manta Network Crowdloan  \
# 1         PRO1                     HALO
# 2         PRO2                    Mizar
# 3         PRO3                     G4AL
# 4         PRO4                 SHELTERZ
# ...        ...                      ...
# 1357   PRO1357          Ozone Metaverse
# 1358   PRO1358                    Hatom
# 1359   PRO1359                   Arkham
# 1360   PRO1360              SophiaVerse
# 1361   PRO1361            Immunify.Life
#
#                                             Description Ticker
# 0     Manta Network is the plug-and-play privacy-pre...  MANTA
# 1     HALO cooperates with the Decemberentralized 3D...   HALO
# 2     Mizar is a next-gen trading platform where tra...    MZR
# 3     The G4AL Platform is the easiest and fastest a...    GGT
# 4     SHELTERZ is an accommodation booking service w...   TERZ
# ...                                                 ...    ...
# 1357  Ozone is a web based immersive experience buil...  OZONE
# 1358  Hatom is a decentralized, algorithmic protocol...    HTM
# 1359  An Intel-To-Earn Token Powering the Deanonymiz...   ARKM
# 1360  Sophia is a platform for the pursuit of useful...   SOPH
# 1361  Immunify.Life is a transformative and self-sus...    IMM
#
# [1362 rows x 4 columns]

# %%
Project.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1362 entries, 0 to 1361
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ProjectID    1362 non-null   object
#  1   Project      1362 non-null   object
#  2   Description  1361 non-null   object
#  3   Ticker       1344 non-null   object
# dtypes: object(4)
# memory usage: 42.7+ KB

# %%
# Create a Category dimension table
Category = df[['Category']].drop_duplicates().reset_index(drop=True)

# Assign the CategoryID with the index number and add "CAT" prefix
Category['CategoryID'] = 'CAT' + Category.index.astype(str)

# Rearrange the table
Category = Category[['CategoryID', 'Category']]
Category
# Out:
#    CategoryID            Category
# 0        CAT0            Protocol
# 1        CAT1  Blockchain Service
# 2        CAT2            Platform
# 3        CAT3                DeFi
# 4        CAT4              Gaming
# 5        CAT5               AI/VR
# 6        CAT6            Exchange
# 7        CAT7             Network
# 8        CAT8    Trading Platform
# 9        CAT9         Marketplace
# 10      CAT10        Data Service
# 11      CAT11            Business
# 12      CAT12      Social Network
# 13      CAT13           Education
# 14      CAT14              Energy
# 15      CAT15          Healthcare
# 16      CAT16        KYC/Security
# 17      CAT17   Marketing Service
# 18      CAT18         Real Estate
# 19      CAT19               Cloud
# 20      CAT20          E-commerce
# 21      CAT21                 IOT
# 22      CAT22              Travel

# %%
Category.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CategoryID  23 non-null     object
#  1   Category    23 non-null     object
# dtypes: object(2)
# memory usage: 496.0+ bytes

# %%
# Create a Platform dimension table
Platform = df[['Platform']].drop_duplicates().reset_index(drop=True)

# Assign the PlatformID with the index number and add "PLAT" prefix
Platform['PlatformID'] = 'PLAT' + Platform.index.astype(str)

# Rearrange the table
Platform = Platform[['PlatformID', 'Platform']]
Platform
# Out:
#    PlatformID             Platform
# 0       PLAT0             Polkadot
# 1       PLAT1        Binance Chain
# 2       PLAT2             Ethereum
# 3       PLAT3               Solana
# 4       PLAT4       Own Blockchain
# 5       PLAT5      NEAR Blockchain
# 6       PLAT6                Tezos
# 7       PLAT7      Flow/Solana/BSC
# 8       PLAT8              Polygon
# 9       PLAT9               Kusama
# 10     PLAT10         Flow Network
# 11     PLAT11        IoTeX Network
# 12     PLAT12           Heco Chain
# 13     PLAT13       Elrond Network
# 14     PLAT14             Algorand
# 15     PLAT15       Cosmos Network
# 16     PLAT16       NEO Blockchain
# 17     PLAT17                 ICON
# 18     PLAT18       NEM Blockchain
# 19     PLAT19        Nebulas Chain
# 20     PLAT20           WaykiChain
# 21     PLAT21                  EOS
# 22     PLAT22                 TRON
# 23     PLAT23  Ontology Blockchain
# 24     PLAT24   Harmony Blockchain
# 25     PLAT25              Stellar
# 26     PLAT26      Iost Blockchain
# 27     PLAT27             Wanchain
# 28     PLAT28         Fusion Chain
# 29     PLAT29       Realio Network
# 30     PLAT30       RSK Blockchain

# %%
Platform.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   PlatformID  31 non-null     object
#  1   Platform    31 non-null     object
# dtypes: object(2)
# memory usage: 624.0+ bytes

# %%
# Create a token role dimension table
Token_role = df[['Token_Role']].drop_duplicates().reset_index(drop=True)

# Assign the Token_roleID with the index number and add "TR" prefix
Token_role['Token_roleID'] = 'TR' + Token_role.index.astype(str)

# Rearrange the table
Token_role = Token_role[['Token_roleID', 'Token_Role']]
Token_role
# Out:
#   Token_roleID  Token_Role
# 0          TR0     Utility
# 1          TR1  Governance
# 2          TR2    Security

# %%
Token_role.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Token_roleID  3 non-null      object
#  1   Token_Role    3 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes

# %%
# Create the fact tabele
ICOs = df.merge(Project, on=['Project', 'Description', 'Ticker']) \
        .merge(Token_role, on='Token_Role') \
        .merge(Platform, on='Platform') \
        .merge(Category, on='Category') \
        .merge(Date, on=['Start_date', 'End_date'])

# Assign the PlatformID with the index number 
ICOs['ICO_ID'] = 'ICO' + ICOs.index.astype(str)

# Rearrange the fact table
ICOs = ICOs[['ICO_ID', 'DateID', 'ProjectID', 'PlatformID', 'CategoryID', 'Token_roleID', 'Raised_usd', 'ICO_price', 'Fundraise_goal', 'Total_token', 'Sold']]

# %%
# change raised usd to an int
ICOs['Raised_usd'] = ICOs['Raised_usd'].astype(float)

# change ico price to a float
ICOs['ICO_price'] = ICOs['ICO_price'].astype(float)

# change % sold to a float
ICOs['Sold'] = ICOs['Sold'].astype(float)

ICOs
# Out:
#        ICO_ID  DateID ProjectID PlatformID CategoryID Token_roleID
# 0        ICO0     DA0      PRO0      PLAT0       CAT0          TR0  \
# 1        ICO1    DA39     PRO46      PLAT0       CAT0          TR0
# 2        ICO2   DA309    PRO367      PLAT0       CAT0          TR0
# 3        ICO3   DA309    PRO368      PLAT2       CAT2          TR0
# 4        ICO4   DA309    PRO369      PLAT1       CAT4          TR0
# ...       ...     ...       ...        ...        ...          ...
# 1358  ICO1358   DA788    PRO887     PLAT16      CAT16          TR0
# 1359  ICO1359   DA884    PRO991      PLAT2      CAT20          TR0
# 1360  ICO1360   DA965   PRO1073      PLAT4      CAT21          TR0
# 1361  ICO1361  DA1052   PRO1171     PLAT26      CAT21          TR0
# 1362  ICO1362  DA1170   PRO1296      PLAT3      CAT22          TR0
#
#       Raised_usd  ICO_price  Fundraise_goal   Total_token  Sold
# 0      6600000.0        NaN             NaN  1.000000e+09  15.6
# 1       240000.0       0.25        240000.0           NaN   NaN
# 2      6600000.0       0.36      28800000.0  1.000000e+09   NaN
# 3      5500000.0       0.01        200000.0  1.000000e+10   NaN
# 4      1810000.0       0.16         50000.0  1.000000e+08   NaN
# ...          ...        ...             ...           ...   ...
# 1358  25000000.0       0.05             NaN  1.000000e+09  50.0
# 1359   7000000.0       0.12             NaN  1.000000e+09  23.0
# 1360  15480000.0       0.01       1000000.0           NaN  20.0
# 1361   3710000.0       0.01       2000000.0  2.000000e+09   NaN
# 1362    300000.0       0.15        300000.0  1.000000e+10   5.0
#
# [1363 rows x 11 columns]

# %%
ICOs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1363 entries, 0 to 1362
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ICO_ID          1363 non-null   object
#  1   DateID          1363 non-null   object
#  2   ProjectID       1363 non-null   object
#  3   PlatformID      1363 non-null   object
#  4   CategoryID      1363 non-null   object
#  5   Token_roleID    1363 non-null   object
#  6   Raised_usd      1271 non-null   float64
#  7   ICO_price       1104 non-null   float64
#  8   Fundraise_goal  843 non-null    float64
#  9   Total_token     1217 non-null   float64
#  10  Sold            705 non-null    float64
# dtypes: float64(5), object(6)
# memory usage: 117.3+ KB

# %%
# Convert all tables to a csv files
Date.to_csv('Date(DimT).csv', index = False)
Project.to_csv('Project(DimT).csv', index = False)
Category.to_csv('Category(DimT).csv', index = False)
Platform.to_csv('Platform(DimT).csv', index = False)
Token_role.to_csv('Token_role(DimT).csv', index = False)
ICOs.to_csv('ICOs(Fact Table).csv', index = False)
